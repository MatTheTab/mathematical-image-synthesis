# %%
from utils.comparison import *

# %% [markdown]
# ## Matplotlib-generated images

# %%
k = np.arange(1, 7001)

a1 = np.cos(2 * np.pi * k / 7000)
b1 = np.sin(18 * np.pi * k / 7000) ** 3
r1 = (1/4) * (np.cos(42 * np.pi * k / 7000)) ** 2
img1 = generate_image(k, a1, b1, r1)

a2 = np.cos(1.5 * np.pi * k / 6999)
b2 = np.sin(19 * np.pi * k / 6999) ** 3
r2 = (1/5) * (np.cos(42 * np.pi * k / 6999)) ** 2
img2 = generate_image(k, a2, b2, r2)

a3 = np.cos(2 * np.pi * k / 6700)
b3 = np.sin(18 * np.pi * k / 7100) ** 4
r3 = (1/8) * (np.cos(42 * np.pi * k / 700)) ** 3
img3 = generate_image(k, a3, b3, r3)

a4 = np.cos(2 * np.pi * k / 70)
b4 = np.sin(18 * np.pi * k) ** 21
r4 = (1/4) * (np.cos(42 * np.pi * k / 700)) ** 2
img4 = generate_image(k, a4, b4, r4)

images = [img1, img2, img3, img4]

processed = [preprocess(im) for im in images]
results = [calculate_metrics(processed[0], processed[i]) for i in range(4)]
plot_comparison(images, results)
# Out:
# /home/mati/image-synthesis/image-synthesis-venv/lib/python3.12/site-packages/skimage/metrics/simple_metrics.py:168: RuntimeWarning: divide by zero encountered in scalar divide
#   return 10 * np.log10((data_range**2) / err)

# %%
k = np.arange(1, 8001)

a1 = np.cos(6*np.pi*k/8000)
b1 = np.sin(22*np.pi*k/8000)**3
r1 = 1/5 * (np.sin(58*np.pi*k/8000))**2
img1 = generate_image(k, b1, a1, r1)

a2 = np.cos(5*np.pi*k/7999)
b2 = np.sin(21*np.pi*k/7999)**3
r2 = 1/4 * (np.sin(58*np.pi*k/7999))**2
img2 = generate_image(k, a2, b2, r2)

a3 = np.cos(5*np.pi*k/8500)
b3 = np.sin(21*np.pi*k/500)**4
r3 = 1/3 * (np.sin(58*np.pi*k/7999))**2
img3 = generate_image(k, a3, b3, r3)

a4 = np.cos(6*np.pi*k/800)
b4 = np.sin(22*np.pi*k/80)**30
r4 = 1/5 * (np.cos(58*np.pi*k/8000))
img4 = generate_image(k, a4, b4, r4)

images = [img1, img2, img3, img4]

results = [calculate_metrics(processed[0], processed[i]) for i in range(4)]
plot_comparison(images, results)
# Out:
# /home/mati/image-synthesis/image-synthesis-venv/lib/python3.12/site-packages/skimage/metrics/simple_metrics.py:168: RuntimeWarning: divide by zero encountered in scalar divide
#   return 10 * np.log10((data_range**2) / err)

# %%
k = np.arange(1, 9831)

k1 = (k - 10000) / 10000
k2 = (k - 10000) / 100000

X = (
    (np.sin(np.pi * k / 20000))**12 *
    (
        1/2 * (np.cos(31 * np.pi * k / 10000))**16 * np.sin(6 * np.pi * k / 10000) +
        1/6 * (np.sin(31 * np.pi * k / 10000))**20
    )
    + 3 * k / 20000
    + (np.cos(31 * np.pi * k / 10000))**6 * np.sin((np.pi / 2) * k1**7 - np.pi / 5)
)

Y = (
    -9/4 * (np.cos(31 * np.pi * k / 10000))**6 *
    np.cos((np.pi / 2) * k1**7 - np.pi / 5) *
    (2/3 + (np.sin(np.pi * k / 20000) * np.sin(3 * np.pi * k / 20000))**6)
    +
    3/4 *
    (np.cos(3 * np.pi * k2))**10 *
    (np.cos(9 * np.pi * k2))**10 *
    (np.cos(36 * np.pi * k2))**14
    +
    7/10 * k1**2
)


R = (
    (np.sin(np.pi * k / 20000))**10 *
    (
        1/4 * (np.cos(31 * np.pi * k / 10000 + 25 * np.pi / 32))**20 +
        1/20 * (np.cos(31 * np.pi * k / 10000))**2
    ) +
    1/30 * (3/2 - (np.cos(62 * np.pi * k / 10000))**2)
)
img1 = generate_image(k, X, Y, R, xlim1 = -1.5, xlim2 = 2.5, ylim1 = -3.5, ylim2 = 2.5)

k1 = (k - 1000) / 10000
k2 = (k - 10000) / 100000

X = (
    (np.sin(np.pi * k / 20000))**12 *
    (
        1/2 * (np.cos(31 * np.pi * k / 10000))**15 * np.sin(6 * np.pi * k / 10000) +
        1/6 * (np.sin(31 * np.pi * k / 10000))**20
    )
    + 3 * k / 20000
    + (np.cos(31 * np.pi * k / 10000))**6 * np.sin((np.pi / 2) * k1**7 - np.pi / 5)
)

Y = (
    -9/4 * (np.cos(31 * np.pi * k / 10000))**6 *
    np.cos((np.pi / 2) * k1**7 - np.pi / 5) *
    (2/3 + (np.sin(np.pi * k / 20000) * np.sin(3 * np.pi * k / 20000))**6)
    +
    3/4 *
    (np.cos(3 * np.pi * k2))**10 *
    (np.cos(9 * np.pi * k2))**10 *
    (np.cos(36 * np.pi * k2))**14
    +
    7/10 * k1**2
)


R = (
    (np.sin(np.pi * k / 20000))**10 *
    (
        1/4 * (np.cos(31 * np.pi * k / 10000 + 25 * np.pi / 32))**20 +
        1/20 * (np.cos(31 * np.pi * k / 10000))**2
    ) +
    1/30 * (3/2 - (np.cos(62 * np.pi * k / 10000))**2)
)
img2 = generate_image(k, X, Y, R, xlim1 = -1.5, xlim2 = 2.5, ylim1 = -3.5, ylim2 = 2.5)

k1 = (k - 1000) / 10000
k2 = (k - 10000) / 100000

X = (
    (np.sin(np.pi * k / 20000))**12 *
    (
        1/2 * (np.cos(31 * np.pi * k / 10000))**15 * np.sin(6 * np.pi * k / 10000) +
        1/6 * (np.sin(31 * np.pi * k / 10000))**20
    )
    + 3 * k / 20000
    + (np.cos(31 * np.pi * k / 10000))**6 * np.sin((np.pi / 2) * k1**7 - np.pi / 5)
)

Y = (
    -9/4 * (np.cos(31 * np.pi * k / 10000))**3 *
    np.cos((np.pi / 2) * k1**7 - np.pi / 5) *
    (2/3 + (np.sin(np.pi * k / 20000) * np.sin(3 * np.pi * k / 20000))**6)
    +
    3/4 *
    (np.cos(3 * np.pi * k2))**10 *
    (np.cos(9 * np.pi * k2))**10 *
    (np.cos(36 * np.pi * k2))**14
    +
    7/10 * k1**2
)


R = (
    (np.sin(np.pi * k / 20000))**10 *
    (
        1/4 * (np.cos(31 * np.pi * k / 10000 + 25 * np.pi / 32))**20 +
        1/20 * (np.cos(31 * np.pi * k / 10000))**2
    ) +
    1/30 * (3/2 - (np.cos(62 * np.pi * k / 10000))**2)
)
img3 = generate_image(k, X, Y, R, xlim1 = -1.5, xlim2 = 2.5, ylim1 = -3.5, ylim2 = 2.5)

k1 = (k - 100) / 10000
k2 = (k - 10000) / 100000

X = (
    (np.sin(np.pi * k / 20000))**12 *
    (
        1/9 * (np.cos(31 * np.pi * k / 10000))**16 * np.sin(6 * np.pi * k / 10000) +
        1/21 * (np.sin(310 * np.pi * k / 10000))**20
    )
    + 3 * k / 20000
    + (np.cos(31 * np.pi * k / 100))**6 * np.sin((np.pi / 2) * k1**7 - np.pi / 5)
)

Y = (
    -9/4 * (np.cos(31 * np.pi * k / 10000))**6 *
    np.cos((np.pi / 2) * k1**9 - np.pi / 5) *
    (2/3 + (np.sin(np.pi * k / 20000) * np.sin(3 * np.pi * k / 2000))**6)
    +
    3/4 *
    (np.cos(3 * np.pi * k2))**10 *
    (np.cos(9 * np.pi * k2))**10 *
    (np.cos(36 * np.pi * k2))**14
    +
    7/10 * k1**2
)


R = (
    (np.sin(np.pi * -k / 20000))**10 *
    (
        1/4 * (np.cos(31 * np.pi * k / 10000 + 25 * np.pi / 32))**20 +
        1/20 * (np.cos(31 * np.pi * k / 10000))**2
    ) +
    1/30 * (3/2 - (np.cos(62 * np.pi * k / 10000))**2)
)
img4 = generate_image(k, X, Y, R, xlim1 = -1.5, xlim2 = 2.5, ylim1 = -3.5, ylim2 = 2.5)

images = [img1, img2, img3, img4]

processed = [preprocess(im) for im in images]

results = [calculate_metrics(processed[0], processed[i]) for i in range(4)]
plot_comparison(images, results)
# Out:
# /home/mati/image-synthesis/image-synthesis-venv/lib/python3.12/site-packages/skimage/metrics/simple_metrics.py:168: RuntimeWarning: divide by zero encountered in scalar divide
#   return 10 * np.log10((data_range**2) / err)

# %% [markdown]
# ## To-pixel imgs

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = x**2 + y**2 - 1089
    return safe_exp_exp(value)

def B(x, y):
    value1 = x**2 + y**2 - 1225
    value2 = -1000 * (np.sin(0.3*x - 0.7*y) + 4*np.sin(0.3*x + 0.5*y))
    return safe_exp_exp(value1) * safe_exp_exp(value2)

def Jc(x, y, c):
    return (1 - D(x, y)) * (1 - B(x, y)) * (-0.07 * c**2 + 0.18 * c + 0.88) \
           * safe_exp_exp(y**2 - 20_000) * safe_exp_exp(-20 * (np.sin(x) + np.cos(y)))

def Ic(x, y, c):
    return (1 - D(x, y)) * (1 - B(x, y)) * (-0.02 * c**2 + 0.23*c + 0.04) \
           * safe_exp_exp(10 * (np.sin(x) + np.cos(y)))

def Hc(x, y, c):
    return (0.15 * c**2 - 0.76 * c + 1.6) * B(x, y) + (1 - B(x, y)) * 0.93 * D(x, y)

def Ac(x, y, c):
    return 255 * (Hc(x, y, c) + Ic(x, y, c) + Jc(x, y, c))

def rgb(x, y, c):
    return Ac((x - 800) / 10, (500 - y) / 10, c)

img1 = generate_pixel_img(rgb, 1600, 1000)

# plt.figure(figsize=(10, 6))
# plt.imshow(img1)
# plt.axis('off')
# plt.title("ball")
# plt.show()

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = x**2 + y**2 - 1089
    return safe_exp_exp(value)

def B(x, y):
    value1 = x**2 + y**2 - 1225
    value2 = -1000 * (np.sin(0.3*x - 0.7*y) + 4*np.sin(0.3*x + 0.5*y))
    return safe_exp_exp(value1) * safe_exp_exp(value2)

def Jc(x, y, c):
    return (1 - D(x, y)) * (1 - B(x, y)) * (-0.07 * c**2 + 0.18 * c + 0.88) \
           * safe_exp_exp(y**2 - 20_000) * safe_exp_exp(-20 * (np.sin(x) + np.cos(y)))

def Ic(x, y, c):
    return (1 - B(x, y)) * (1 - B(x, y)) * (-0.15 * c**2 + 0.23*c + 0.88) \
           * safe_exp_exp(10 * (np.sin(x) + np.cos(y)))

def Hc(x, y, c):
    return 0.15 * (c*2 - 0.76) * c + 1.6 * (1 - B(x, y)) + (1 - B(x, y)) * 0.15 * D(x, y)

def Ac(x, y, c):
    return 255 * (Hc(x, y, c) + Ic(x, y, c) + Jc(x, y, c))

def rgb(x, y, c):
    return Ac((x - 800) / 10, (500 - y) / 10, c)

img2 = generate_pixel_img(rgb, 1600, 1000)

# plt.figure(figsize=(10, 6))
# plt.imshow(img1)
# plt.axis('off')
# plt.title("ball")
# plt.show()

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = x**2 + y**2 - 1089
    return safe_exp_exp(value)

def B(x, y):
    value1 = x**2 + y**2 - 1225
    value2 = -1000 * ((np.sin(0.3*x - 0.7*y) + np.cos(0.3*x + 0.5*y))) * np.cos(0.3*x + 0.5*y)
    return safe_exp_exp(value1) * safe_exp_exp(value2)

def Jc(x, y, c):
    return (1 - D(x, y)) * (1 - B(x, y)) * (-0.07 * c**2 + 0.18 * c + 0.88) \
           * safe_exp_exp(y**2 - 0.07)

def Ic(x, y, c):
    return (1 - D(x, y))

def Hc(x, y, c):
    return (0.15 * c**2 - 0.76 * c + 1.6) * B(x, y) + (1 - B(x, y)) * 0.93 * D(x, y) \
           * safe_exp_exp(10 * (np.sin(x) + np.cos(y))) * safe_exp_exp(-20 * (np.sin(x) + np.cos(y)))

def Ac(x, y, c):
    return 255 * (Hc(x, y, c) + Ic(x, y, c) + Jc(x, y, c))

def rgb(x, y, c):
    return Ac((x - 800) / 10, (500 - y) / 10, c)

img3 = generate_pixel_img(rgb, 1600, 1000)

# plt.figure(figsize=(10, 6))
# plt.imshow(img3)
# plt.axis('off')
# plt.title("ball")
# plt.show()

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = x**2 + np.sin(x) - 1089
    return safe_exp_exp(value)

def B(x, y):
    value1 = x**2 + y*x*x - 0.07
    value2 = 0.18
    return safe_exp_exp(value1) * safe_exp_exp(value2)

def Jc(x, y, c):
    return (1 - D(x, y)) * (1 - B(x, y)) * (-0.07 * c*2 + 0.18 * c + 0.88) \
        * (-0.07 * y*2 + 0.18 * c + 0.88) * (-0.07 * x*2 + 0.18 * x + 0.88)

def Ic(x, y, c):
    return (1 - D(x, y)) * (1 - B(x, y)) * (-0.02 * c**2 + 0.23*c + 0.04) \
           * safe_exp_exp(10 * (np.sin(x) + np.cos(y)))

def Hc(x, y, c):
    return (0.15 * c**2 - 0.76 * c + 1.6) * B(x, y) + (1 - B(x, y)) * 0.93 * D(x, y)

def Ac(x, y, c):
    return 255 * (Hc(x, y, c) + Ic(x, y, c) + Jc(x, y, c))

def rgb(x, y, c):
    return Ac((x - 800) / 10, (500 - y) / 10, c)

img4 = generate_pixel_img(rgb, 1600, 1000)

# plt.figure(figsize=(10, 6))
# plt.imshow(img4)
# plt.axis('off')
# plt.title("ball")
# plt.show()

# %%
images = [img1, img2, img3, img4]
results = [calculate_metrics(images[0], images[i]) for i in range(4)]
plot_comparison(images, results)
# Out:
# c:\Users\Bartek\AppData\Local\Programs\Python\Python312\Lib\site-packages\skimage\metrics\simple_metrics.py:168: RuntimeWarning: divide by zero encountered in scalar divide
#   return 10 * np.log10((data_range**2) / err)

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = 1.25 - safe_exp_exp(1000 * (y-7*np.abs(x)+0.25)) * safe_exp_exp(-1000 * (-y-7*np.abs(x) + 3))
    return value

def B(x, y):
    value = D(x, y) * safe_exp_exp(-2000 * (y-1.01)) + 1.1 - safe_exp_exp(-500 * (-y-7*np.abs(x)+3)) + safe_exp_exp(1000 * (y-0.7))
    return value

def A(x, y):
    return safe_exp_exp(-1000 * (y-1.4)) + safe_exp_exp(-1000 * (-y - (0.8 * pow(12, -np.abs(x))) - 0.05)) + \
        safe_exp_exp(1000 * (-y + pow(400, np.abs(x)-2) + 0.8)) + safe_exp_exp(-5000 * (-y - 0.1*pow(4.7, -np.abs(x) + 5.15) - 0.05 + 2))

def f(x, y, p):
    return safe_exp_exp(100 * (A(x,y) * B(x,y) - 1)) * 200 * p + 55

def rgb(x, y, p):
    return f((x-500)/100, (300-y)/100, p)

img1 = generate_pixel_img(rgb, 1000, 600, c=[1,0.2,0.2])

# plt.figure(figsize=(10, 6))
# plt.imshow(img1)
# plt.axis('off')
# plt.title("bat")
# plt.show()

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = 1.01 - safe_exp_exp(1000 * (x*y-4*np.abs(x)+0.05))
    return value

def B(x, y):
    value = D(x, y) * safe_exp_exp(-2000 * (y-1.01)) + 1.1 - safe_exp_exp(-500 * (-y-7*np.abs(x)+3))
    return value

def A(x, y):
    return safe_exp_exp(-1000 * (y-1.4)) + safe_exp_exp(-1000 * (-y - (0.8 * pow(12, -np.abs(x))) - 0.05)) + \
        safe_exp_exp(1000 * (-y + pow(400, np.abs(x)-2) + 0.8)) + safe_exp_exp(-5000 * (-y - 0.1*pow(4.7, -np.abs(x) + 5.15) - 0.05 + 2))

def f(x, y, p):
    return safe_exp_exp(100 * (A(x,y) * B(x,y) - 1)) * 200 * p + 55

def rgb(x, y, p):
    return f((x-500)/100, (300-y)/100, p)

img3 = generate_pixel_img(rgb, 1000, 600, c=[1,0.2,0.2])

plt.figure(figsize=(10, 6))
plt.imshow(img3)
plt.axis('off')
plt.title("bat")
plt.show()

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = 1.25 - safe_exp_exp(1000 * (y-7*np.abs(x)+0.25)) * safe_exp_exp(-1000 * (-y-7*np.abs(x) + 3))
    return value

def B(x, y):
    value = D(x, y) * safe_exp_exp(-2000 * (y-1.01)) + 1.1 - safe_exp_exp(-500 * (-y-7*np.abs(x)+3)) + safe_exp_exp(1000 * (y-0.7))
    return value

def A(x, y):
    return safe_exp_exp(-0.8 * (-y - (0.8 * pow(12, -np.abs(x))) - 0.05)) + \
        safe_exp_exp(1000 * (-y + pow(400, np.abs(x)-2) + 0.8)) + safe_exp_exp(-5000 * (-y - 0.1*pow(4.7, -np.abs(x) + 5.15) - 0.05 + 2))

def f(x, y, p):
    return safe_exp_exp(1.25 * (A(x,y) * B(x,y) - 1)) * 1000 * p + 1000

def rgb(x, y, p):
    return f((x-500)/100, (300-y)/100, p)

img4 = generate_pixel_img(rgb, 1000, 600, c=[1,0.2,0.2])

plt.figure(figsize=(10, 6))
plt.imshow(img4)
plt.axis('off')
plt.title("bat")
plt.show()

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = safe_exp_exp(1000 * (y-7*np.abs(x) + np.abs(y))) * safe_exp_exp(-1000 * (-y-7*np.abs(x) + 3))
    return value

def B(x, y):
    value = (1 - D(x, y)) + D(x,y) * safe_exp_exp(-0.8 * (y-1.01))**2 + safe_exp_exp(1000 * (y-0.7)) + safe_exp_exp(-2000 * x)
    return value

def A(x, y):
    return safe_exp_exp(-2000 - y - (0.8 - 0.05)) + \
        safe_exp_exp(0.8 * (-y + pow(400, np.abs(x)-2) + 0.8)) + safe_exp_exp(-5000 * (-y - 0.1*pow(4.7, -np.abs(x) + 5.15) - 0.05 + 2)) * \
        safe_exp_exp(-5000 * (1000*pow(0.8, 5.15) + x))

def f(x, y, p):
    return safe_exp_exp(1.25 * (A(x,y) * B(x,y) - 1)) * 1000 * p + 1000

def rgb(x, y, p):
    return f((x-500)/100, (300-y)/100, p)

img5 = generate_pixel_img(rgb, 1000, 600, c=[1,0.2,0.2])

plt.figure(figsize=(10, 6))
plt.imshow(img5)
plt.axis('off')
plt.title("bat")
plt.show()

# %%
def safe_exp_exp(val):
    val = np.where(val > 700, 700, val)
    return np.exp(-np.exp(val))

def D(x, y):
    value = safe_exp_exp(1000 * (y-7*np.abs(x) + np.abs(y))) * safe_exp_exp(-5000 * (-y - 0.1*pow(4.7, -np.abs(x) + 5.15) - 0.05 + 2))
    return value

def B(x, y):
    value = (1 - D(x, y)) + D(x,y) * safe_exp_exp(-0.8 * (y-1.01))**2 + safe_exp_exp(1000 * (y-0.7)) + safe_exp_exp(-2000 * x) * \
        safe_exp_exp(-5000 * (-y - 0.1*pow(4.7, -np.abs(x) + 5.15) - 0.05 + 2))
    return value

def A(x, y):
    return safe_exp_exp(1000 * (y-7*np.abs(x) + np.abs(y))) + safe_exp_exp(-5000 * (-y - 0.1*pow(4.7, -np.abs(x) + 5.15) - 0.05 + 2))

def f(x, y, p):
    return safe_exp_exp(1.25 * (A(x,y) * B(x,y) - 1)) * 1000 * p + 1000

def rgb(x, y, p):
    return f((x-500)/100, (300-y)/100, p)

img6 = generate_pixel_img(rgb, 1000, 600, c=[1,0.2,0.2])

plt.figure(figsize=(10, 6))
plt.imshow(img6)
plt.axis('off')
plt.title("bat")
plt.show()

# %%
images = [img1, img3, img4, img5, img6]
results = [calculate_metrics(images[0], images[i]) for i in range(5)]
plot_comparison(images[:-1], results[:-1])
# Out:
# c:\Users\Bartek\AppData\Local\Programs\Python\Python312\Lib\site-packages\skimage\metrics\simple_metrics.py:168: RuntimeWarning: divide by zero encountered in scalar divide
#   return 10 * np.log10((data_range**2) / err)

# %%
plot_comparison([images[0]] + images[2:], results[1:])
